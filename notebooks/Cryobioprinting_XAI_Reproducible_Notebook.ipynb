# %% [markdown]
# # From Prediction to Design Rules: Reproducible XAI Workflow
#
# This notebook runs the same data preparation, validation, and analysis scripts provided in the repository. The command-line route in `RUN_ORDER.md` is preferred for a formal reproducibility check.

# %% [markdown]
# ## Interpretation boundary
#
# The workflow performs a secondary analysis of the published GelMA-HUVEC cryobioprinting dataset. The resulting CPA rules are local, data-supported hypotheses within the reported design space and should not be interpreted as causal or universal principles.

# %%
from pathlib import Path

cwd = Path.cwd().resolve()
if (cwd / 'scripts' / 'run_pipeline.py').exists():
    PROJECT_ROOT = cwd
elif (cwd.parent / 'scripts' / 'run_pipeline.py').exists():
    PROJECT_ROOT = cwd.parent
else:
    raise FileNotFoundError('Open this notebook from the repository root or notebooks directory.')

PROJECT_ROOT

# %%
# %pip install -r {PROJECT_ROOT / 'requirements.txt'}

# %%
# %cd {PROJECT_ROOT}
# %run scripts/prepare_data.py
# %run scripts/validate_dataset.py

# %%
# %run scripts/run_pipeline.py

# %% [markdown]
# ## Outputs
#
# Generated tables, figures, and model files are written under `outputs/`. A compressed copy is written to `outputs_package.zip`. Compare the main metrics with `docs/EXPECTED_RESULTS.md`.
